# %% [markdown]
# # Random

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate some random data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# %%
# Plot the data
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title("Sine Wave")
plt.show()
